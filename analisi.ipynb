# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math
from matplotlib.ticker import ScalarFormatter

# %%
# Variabili globali

path_old = ["experiments/obdf-resultAnalysis/resultFiles_old/20000.csv","experiments/obdf-resultAnalysis/resultFiles_old/200000.csv"]

path_new = ["experiments/obdf-resultAnalysis/resultFiles-Last/20000.csv","experiments/obdf-resultAnalysis/resultFiles-Last/200000.csv"]

# %%
all_result = []
all_result_old = []

for a,b in zip(path_new,path_old):
    all_result.append(pd.read_csv(a))
    all_result_old.append(pd.read_csv(b))

# %%
# Rimozione della colonna in più per tutti i dataframe

for a in range(0,len(path_old)):
    all_result[a] = all_result[a].loc[:,~all_result[a].columns.str.match("Unnamed")]
    all_result_old[a] = all_result_old[a].loc[:,~all_result_old[a].columns.str.match("Unnamed")]

# %%
# Andiamo a stampare il barplot con i risultati

ax = all_result[0].plot.bar(rot=0,figsize=(12,8))
ax.set_xticks(range(0,13),all_result[0]['query'].values)
ax.set_yscale('log')
ax.yaxis.set_major_formatter(ScalarFormatter())
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05),
          fancybox=True, shadow=True, ncol=8)

# %%
for num,acqui in zip(range(0,len(path_old)),['20000','200000']):

    ax = all_result[num].plot.bar(rot=0,figsize=(12,8))
    ax.set_xticks(range(0,13),all_result[0]['query'].values)
    ax.set_title('Analisi del nuovo datset da '+acqui)
    ax.set_xlabel('Query')
    ax.set_ylabel('tempo medio di esecuzione su scala log.')
    ax.set_yscale('log')
    ax.xaxis.set_label_coords(.08, -.05)
    ax.yaxis.set_major_formatter(ScalarFormatter())
    ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.08),
            fancybox=True, shadow=True, ncol=8,title='profili')

# %%
for num,acqui in zip(range(0,len(path_new)),['20000','200000']):

    ax = all_result_old[num].plot.bar(rot=0,figsize=(12,8))
    ax.set_xticks(range(0,13),all_result[0]['query'].values)
    ax.set_title('Analisi del vecchio datset da '+acqui)
    ax.set_xlabel('Query')
    ax.set_ylabel('tempo medio di esecuzione su scala log.')
    ax.set_yscale('log')
    ax.xaxis.set_label_coords(.08, -.05)
    ax.yaxis.set_major_formatter(ScalarFormatter())
    ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.08),
            fancybox=True, shadow=True, ncol=8,title='profili')

# %%
f = open("experiments/obda-mixer/results/20000/mixer-stats-sc1.txt", "r")
print(f.read())
# Out:
# [GLOBAL]
# [main] [load-time] = 0
# [thread#0]
# [run#5] [num_results#05.sql] = 507
# [run#5] [num_results#11.sql] = 12
# [run#5] [num_results#00.sql] = 93
# [run#5] [num_results#03.sql] = 70
# [run#5] [num_results#02.sql] = 2009
# [run#5] [num_results#07.sql] = 2
# [run#5] [num_results#09.sql] = 32
# [run#5] [num_results#12.sql] = 105
# [run#5] [num_results#01.sql] = 16
# [run#5] [num_results#06.sql] = 1
# [run#5] [num_results#04.sql] = 17
# [run#5] [num_results#08.sql] = 6
# [run#5] [num_results#10.sql] = 6
# [run#5] [rewriting_time#04.sql] = 0
# [run#5] [resultset_traversal_time#11.sql] = 0
# [run#5] [mix_time#5] = 351
# [run#5] [execution_time#07.sql] = 47
# [run#5] [unfolding_time#10.sql] = 0
# [run#5] [resultset_traversal_time#02.sql] = 0
# [run#5] [execution_time#08.sql] = 30
# [run#5] [unfolding_time#03.sql] = 0
# [run#5] [unfolding_time#12.sql] = 0
# [run#5] [rewriting_time#05.sql] = 0
# [run#5] [resultset_traversal_time#10.sql] = 0
# [run#5] [execution_time#06.sql] = 116
# [run#5] [unfolding_time#04.sql] = 0
# [run#5] [resultset_traversal_time#01.sql] = 0
# [run#5] [unfolding_time#00.sql] = 0
# [run#5] [resultset_traversal_time#05.sql] = 0
# [run#5] [rewriting_time#10.sql] = 0
# [run#5] [execution_time#05.sql] = 16
# [run#5] [resultset_traversal_time#00.sql] = 0
# [run#5] [unfolding_time#09.sql] = 0
# [run#5] [rewriting_time#02.sql] = 0
# [run#5] [resultset_traversal_time#06.sql] = 0
# [run#5] [unfolding_time#01.sql] = 0
# [run#5] [rewriting_time#03.sql] = 0
# [run#5] [execution_time#04.sql] = 27
# [run#5] [resultset_traversal_time#12.sql] = 0
# [run#5] [resultset_traversal_time#07.sql] = 0
# [run#5] [unfolding_time#02.sql] = 0
# [run#5] [unfolding_time#07.sql] = 0
# [run#5] [rewriting_time#09.sql] = 0
# [run#5] [execution_time#03.sql] = 17
# [run#5] [resultset_traversal_time#08.sql] = 0
# [run#5] [rewriting_time#00.sql] = 0
# [run#5] [execution_time#10.sql] = 23
# [run#5] [execution_time#12.sql] = 2
# [run#5] [resultset_traversal_time#09.sql] = 0
# [run#5] [unfolding_time#08.sql] = 0
# [run#5] [execution_time#02.sql] = 21
# [run#5] [rewriting_time#01.sql] = 0
# [run#5] [execution_time#11.sql] = 2
# [run#5] [execution_time#00.sql] = 1
# [run#5] [rewriting_time#06.sql] = 0
# [run#5] [rewriting_time#07.sql] = 0
# [run#5] [execution_time#01.sql] = 18
# [run#5] [unfolding_time#05.sql] = 0
# [run#5] [resultset_traversal_time#04.sql] = 0
# [run#5] [rewriting_time#11.sql] = 0
# [run#5] [unfolding_time#06.sql] = 0
# [run#5] [execution_time#09.sql] = 31
# [run#5] [rewriting_time#08.sql] = 0
# [run#5] [unfolding_time#11.sql] = 0
# [run#5] [resultset_traversal_time#03.sql] = 0
# [run#5] [rewriting_time#12.sql] = 0
# [run#4] [num_results#05.sql] = 999
# [run#4] [num_results#11.sql] = 12
# [run#4] [num_results#00.sql] = 80
# [run#4] [num_results#03.sql] = 16
# [run#4] [num_results#02.sql] = 1746
# [run#4] [num_results#07.sql] = 4
# [run#4] [num_results#09.sql] = 32
# [run#4] [num_results#12.sql] = 92
# [run#4] [num_results#01.sql] = 2
# [run#4] [num_results#06.sql] = 1
# [run#4] [num_results#04.sql] = 7
# [run#4] [num_results#08.sql] = 15
# [run#4] [num_results#10.sql] = 82
# [run#4] [rewriting_time#04.sql] = 0
# [run#4] [resultset_traversal_time#11.sql] = 0
# [run#4] [mix_time#4] = 414
# [run#4] [execution_time#07.sql] = 48
# [run#4] [unfolding_time#10.sql] = 0
# [run#4] [resultset_traversal_time#02.sql] = 1
# [run#4] [execution_time#08.sql] = 29
# [run#4] [unfolding_time#03.sql] = 0
# [run#4] [unfolding_time#12.sql] = 0
# [run#4] [rewriting_time#05.sql] = 0
# [run#4] [resultset_traversal_time#10.sql] = 0
# [run#4] [execution_time#06.sql] = 117
# [run#4] [unfolding_time#04.sql] = 0
# [run#4] [resultset_traversal_time#01.sql] = 0
# [run#4] [unfolding_time#00.sql] = 0
# [run#4] [resultset_traversal_time#05.sql] = 0
# [run#4] [rewriting_time#10.sql] = 0
# [run#4] [execution_time#05.sql] = 76
# [run#4] [resultset_traversal_time#00.sql] = 0
# [run#4] [unfolding_time#09.sql] = 0
# [run#4] [rewriting_time#02.sql] = 0
# [run#4] [resultset_traversal_time#06.sql] = 0
# [run#4] [unfolding_time#01.sql] = 0
# [run#4] [rewriting_time#03.sql] = 0
# [run#4] [execution_time#04.sql] = 22
# [run#4] [resultset_traversal_time#12.sql] = 0
# [run#4] [resultset_traversal_time#07.sql] = 0
# [run#4] [unfolding_time#02.sql] = 0
# [run#4] [unfolding_time#07.sql] = 0
# [run#4] [rewriting_time#09.sql] = 0
# [run#4] [execution_time#03.sql] = 17
# [run#4] [resultset_traversal_time#08.sql] = 0
# [run#4] [rewriting_time#00.sql] = 0
# [run#4] [execution_time#10.sql] = 26
# [run#4] [execution_time#12.sql] = 2
# [run#4] [resultset_traversal_time#09.sql] = 0
# [run#4] [unfolding_time#08.sql] = 0
# [run#4] [execution_time#02.sql] = 17
# [run#4] [rewriting_time#01.sql] = 0
# [run#4] [execution_time#11.sql] = 2
# [run#4] [execution_time#00.sql] = 2
# [run#4] [rewriting_time#06.sql] = 0
# [run#4] [rewriting_time#07.sql] = 0
# [run#4] [execution_time#01.sql] = 17
# [run#4] [unfolding_time#05.sql] = 0
# [run#4] [resultset_traversal_time#04.sql] = 0
# [run#4] [rewriting_time#11.sql] = 0
# [run#4] [unfolding_time#06.sql] = 0
# [run#4] [execution_time#09.sql] = 38
# [run#4] [rewriting_time#08.sql] = 0
# [run#4] [unfolding_time#11.sql] = 0
# [run#4] [resultset_traversal_time#03.sql] = 0
# [run#4] [rewriting_time#12.sql] = 0
# [run#7] [num_results#05.sql] = 4407
# [run#7] [num_results#11.sql] = 12
# [run#7] [num_results#00.sql] = 119
# [run#7] [num_results#03.sql] = 8
# [run#7] [num_results#02.sql] = 2530
# [run#7] [num_results#07.sql] = 1
# [run#7] [num_results#09.sql] = 21
# [run#7] [num_results#12.sql] = 131
# [run#7] [num_results#01.sql] = 9
# [run#7] [num_results#06.sql] = 1
# [run#7] [num_results#04.sql] = 3
# [run#7] [num_results#08.sql] = 10
# [run#7] [num_results#10.sql] = 28
# [run#7] [rewriting_time#04.sql] = 0
# [run#7] [resultset_traversal_time#11.sql] = 0
# [run#7] [mix_time#7] = 406
# [run#7] [execution_time#07.sql] = 49
# [run#7] [unfolding_time#10.sql] = 0
# [run#7] [resultset_traversal_time#02.sql] = 0
# [run#7] [execution_time#08.sql] = 28
# [run#7] [unfolding_time#03.sql] = 0
# [run#7] [unfolding_time#12.sql] = 0
# [run#7] [rewriting_time#05.sql] = 0
# [run#7] [resultset_traversal_time#10.sql] = 0
# [run#7] [execution_time#06.sql] = 123
# [run#7] [unfolding_time#04.sql] = 0
# [run#7] [resultset_traversal_time#01.sql] = 0
# [run#7] [unfolding_time#00.sql] = 0
# [run#7] [resultset_traversal_time#05.sql] = 0
# [run#7] [rewriting_time#10.sql] = 0
# [run#7] [execution_time#05.sql] = 60
# [run#7] [resultset_traversal_time#00.sql] = 0
# [run#7] [unfolding_time#09.sql] = 0
# [run#7] [rewriting_time#02.sql] = 0
# [run#7] [resultset_traversal_time#06.sql] = 0
# [run#7] [unfolding_time#01.sql] = 0
# [run#7] [rewriting_time#03.sql] = 0
# [run#7] [execution_time#04.sql] = 22
# [run#7] [resultset_traversal_time#12.sql] = 0
# [run#7] [resultset_traversal_time#07.sql] = 0
# [run#7] [unfolding_time#02.sql] = 0
# [run#7] [unfolding_time#07.sql] = 0
# [run#7] [rewriting_time#09.sql] = 0
# [run#7] [execution_time#03.sql] = 16
# [run#7] [resultset_traversal_time#08.sql] = 0
# [run#7] [rewriting_time#00.sql] = 0
# [run#7] [execution_time#10.sql] = 27
# [run#7] [execution_time#12.sql] = 2
# [run#7] [resultset_traversal_time#09.sql] = 0
# [run#7] [unfolding_time#08.sql] = 0
# [run#7] [execution_time#02.sql] = 24
# [run#7] [rewriting_time#01.sql] = 0
# [run#7] [execution_time#11.sql] = 2
# [run#7] [execution_time#00.sql] = 1
# [run#7] [rewriting_time#06.sql] = 0
# [run#7] [rewriting_time#07.sql] = 0
# [run#7] [execution_time#01.sql] = 16
# [run#7] [unfolding_time#05.sql] = 0
# [run#7] [resultset_traversal_time#04.sql] = 0
# [run#7] [rewriting_time#11.sql] = 0
# [run#7] [unfolding_time#06.sql] = 0
# [run#7] [execution_time#09.sql] = 35
# [run#7] [rewriting_time#08.sql] = 0
# [run#7] [unfolding_time#11.sql] = 0
# [run#7] [resultset_traversal_time#03.sql] = 0
# [run#7] [rewriting_time#12.sql] = 0
# [run#6] [num_results#05.sql] = 3537
# [run#6] [num_results#11.sql] = 12
# [run#6] [num_results#00.sql] = 106
# [run#6] [num_results#03.sql] = 292
# [run#6] [num_results#02.sql] = 2277
# [run#6] [num_results#07.sql] = 1
# [run#6] [num_results#09.sql] = 32
# [run#6] [num_results#12.sql] = 118
# [run#6] [num_results#01.sql] = 40
# [run#6] [num_results#06.sql] = 45
# [run#6] [num_results#04.sql] = 132
# [run#6] [num_results#08.sql] = 10
# [run#6] [num_results#10.sql] = 27
# [run#6] [rewriting_time#04.sql] = 0
# [run#6] [resultset_traversal_time#11.sql] = 0
# [run#6] [mix_time#6] = 393
# [run#6] [execution_time#07.sql] = 48
# [run#6] [unfolding_time#10.sql] = 0
# [run#6] [resultset_traversal_time#02.sql] = 1
# [run#6] [execution_time#08.sql] = 29
# [run#6] [unfolding_time#03.sql] = 0
# [run#6] [unfolding_time#12.sql] = 0
# [run#6] [rewriting_time#05.sql] = 0
# [run#6] [resultset_traversal_time#10.sql] = 0
# [run#6] [execution_time#06.sql] = 118
# [run#6] [unfolding_time#04.sql] = 0
# [run#6] [resultset_traversal_time#01.sql] = 0
# [run#6] [unfolding_time#00.sql] = 0
# [run#6] [resultset_traversal_time#05.sql] = 0
# [run#6] [rewriting_time#10.sql] = 0
# [run#6] [execution_time#05.sql] = 54
# [run#6] [resultset_traversal_time#00.sql] = 0
# [run#6] [unfolding_time#09.sql] = 0
# [run#6] [rewriting_time#02.sql] = 0
# [run#6] [resultset_traversal_time#06.sql] = 0
# [run#6] [unfolding_time#01.sql] = 0
# [run#6] [rewriting_time#03.sql] = 0
# [run#6] [execution_time#04.sql] = 23
# [run#6] [resultset_traversal_time#12.sql] = 0
# [run#6] [resultset_traversal_time#07.sql] = 0
# [run#6] [unfolding_time#02.sql] = 0
# [run#6] [unfolding_time#07.sql] = 0
# [run#6] [rewriting_time#09.sql] = 0
# [run#6] [execution_time#03.sql] = 17
# [run#6] [resultset_traversal_time#08.sql] = 0
# [run#6] [rewriting_time#00.sql] = 0
# [run#6] [execution_time#10.sql] = 24
# [run#6] [execution_time#12.sql] = 2
# [run#6] [resultset_traversal_time#09.sql] = 1
# [run#6] [unfolding_time#08.sql] = 0
# [run#6] [execution_time#02.sql] = 22
# [run#6] [rewriting_time#01.sql] = 0
# [run#6] [execution_time#11.sql] = 2
# [run#6] [execution_time#00.sql] = 2
# [run#6] [rewriting_time#06.sql] = 0
# [run#6] [rewriting_time#07.sql] = 0
# [run#6] [execution_time#01.sql] = 17
# [run#6] [unfolding_time#05.sql] = 0
# [run#6] [resultset_traversal_time#04.sql] = 0
# [run#6] [rewriting_time#11.sql] = 0
# [run#6] [unfolding_time#06.sql] = 0
# [run#6] [execution_time#09.sql] = 33
# [run#6] [rewriting_time#08.sql] = 0
# [run#6] [unfolding_time#11.sql] = 0
# [run#6] [resultset_traversal_time#03.sql] = 0
# [run#6] [rewriting_time#12.sql] = 0
# [run#1] [num_results#05.sql] = 2598
# [run#1] [num_results#11.sql] = 12
# [run#1] [num_results#00.sql] = 41
# [run#1] [num_results#03.sql] = 11
# [run#1] [num_results#02.sql] = 922
# [run#1] [num_results#07.sql] = 2
# [run#1] [num_results#09.sql] = 21
# [run#1] [num_results#12.sql] = 53
# [run#1] [num_results#01.sql] = 4
# [run#1] [num_results#06.sql] = 2
# [run#1] [num_results#04.sql] = 7
# [run#1] [num_results#08.sql] = 5
# [run#1] [num_results#10.sql] = 7
# [run#1] [rewriting_time#04.sql] = 0
# [run#1] [resultset_traversal_time#11.sql] = 0
# [run#1] [execution_time#07.sql] = 48
# [run#1] [unfolding_time#10.sql] = 0
# [run#1] [resultset_traversal_time#02.sql] = 0
# [run#1] [execution_time#08.sql] = 30
# [run#1] [unfolding_time#03.sql] = 0
# [run#1] [unfolding_time#12.sql] = 0
# [run#1] [rewriting_time#05.sql] = 0
# [run#1] [resultset_traversal_time#10.sql] = 0
# [run#1] [execution_time#06.sql] = 121
# [run#1] [unfolding_time#04.sql] = 0
# [run#1] [resultset_traversal_time#01.sql] = 0
# [run#1] [unfolding_time#00.sql] = 0
# [run#1] [resultset_traversal_time#05.sql] = 0
# [run#1] [rewriting_time#10.sql] = 0
# [run#1] [execution_time#05.sql] = 46
# [run#1] [resultset_traversal_time#00.sql] = 0
# [run#1] [unfolding_time#09.sql] = 0
# [run#1] [rewriting_time#02.sql] = 0
# [run#1] [resultset_traversal_time#06.sql] = 0
# [run#1] [unfolding_time#01.sql] = 0
# [run#1] [rewriting_time#03.sql] = 0
# [run#1] [execution_time#04.sql] = 22
# [run#1] [resultset_traversal_time#12.sql] = 0
# [run#1] [resultset_traversal_time#07.sql] = 0
# [run#1] [unfolding_time#02.sql] = 0
# [run#1] [unfolding_time#07.sql] = 0
# [run#1] [rewriting_time#09.sql] = 0
# [run#1] [execution_time#03.sql] = 17
# [run#1] [resultset_traversal_time#08.sql] = 0
# [run#1] [rewriting_time#00.sql] = 0
# [run#1] [execution_time#10.sql] = 25
# [run#1] [execution_time#12.sql] = 2
# [run#1] [resultset_traversal_time#09.sql] = 0
# [run#1] [unfolding_time#08.sql] = 0
# [run#1] [execution_time#02.sql] = 10
# [run#1] [rewriting_time#01.sql] = 0
# [run#1] [execution_time#11.sql] = 2
# [run#1] [execution_time#00.sql] = 1
# [run#1] [rewriting_time#06.sql] = 0
# [run#1] [rewriting_time#07.sql] = 0
# [run#1] [execution_time#01.sql] = 16
# [run#1] [unfolding_time#05.sql] = 0
# [run#1] [resultset_traversal_time#04.sql] = 0
# [run#1] [rewriting_time#11.sql] = 0
# [run#1] [unfolding_time#06.sql] = 0
# [run#1] [execution_time#09.sql] = 30
# [run#1] [rewriting_time#08.sql] = 0
# [run#1] [unfolding_time#11.sql] = 0
# [run#1] [resultset_traversal_time#03.sql] = 0
# [run#1] [rewriting_time#12.sql] = 0
# [run#1] [mix_time#1] = 370
# [run#0] [num_results#05.sql] = 880
# [run#0] [num_results#11.sql] = 12
# [run#0] [num_results#00.sql] = 28
# [run#0] [num_results#03.sql] = 52
# [run#0] [num_results#02.sql] = 639
# [run#0] [num_results#07.sql] = 2
# [run#0] [num_results#09.sql] = 21
# [run#0] [num_results#12.sql] = 40
# [run#0] [num_results#01.sql] = 5
# [run#0] [num_results#06.sql] = 1
# [run#0] [num_results#04.sql] = 29
# [run#0] [num_results#08.sql] = 4
# [run#0] [num_results#10.sql] = 8
# [run#0] [rewriting_time#04.sql] = 0
# [run#0] [resultset_traversal_time#11.sql] = 0
# [run#0] [execution_time#07.sql] = 48
# [run#0] [unfolding_time#10.sql] = 0
# [run#0] [resultset_traversal_time#02.sql] = 0
# [run#0] [execution_time#08.sql] = 33
# [run#0] [unfolding_time#03.sql] = 0
# [run#0] [unfolding_time#12.sql] = 0
# [run#0] [rewriting_time#05.sql] = 0
# [run#0] [resultset_traversal_time#10.sql] = 0
# [run#0] [execution_time#06.sql] = 130
# [run#0] [unfolding_time#04.sql] = 0
# [run#0] [resultset_traversal_time#01.sql] = 0
# [run#0] [unfolding_time#00.sql] = 0
# [run#0] [resultset_traversal_time#05.sql] = 0
# [run#0] [rewriting_time#10.sql] = 0
# [run#0] [execution_time#05.sql] = 63
# [run#0] [resultset_traversal_time#00.sql] = 1
# [run#0] [unfolding_time#09.sql] = 0
# [run#0] [rewriting_time#02.sql] = 0
# [run#0] [resultset_traversal_time#06.sql] = 0
# [run#0] [unfolding_time#01.sql] = 0
# [run#0] [rewriting_time#03.sql] = 0
# [run#0] [execution_time#04.sql] = 23
# [run#0] [resultset_traversal_time#12.sql] = 0
# [run#0] [resultset_traversal_time#07.sql] = 0
# [run#0] [unfolding_time#02.sql] = 0
# [run#0] [unfolding_time#07.sql] = 0
# [run#0] [rewriting_time#09.sql] = 0
# [run#0] [execution_time#03.sql] = 16
# [run#0] [resultset_traversal_time#08.sql] = 0
# [run#0] [rewriting_time#00.sql] = 0
# [run#0] [execution_time#10.sql] = 24
# [run#0] [execution_time#12.sql] = 2
# [run#0] [resultset_traversal_time#09.sql] = 0
# [run#0] [unfolding_time#08.sql] = 0
# [run#0] [execution_time#02.sql] = 8
# [run#0] [rewriting_time#01.sql] = 0
# [run#0] [execution_time#11.sql] = 2
# [run#0] [execution_time#00.sql] = 1
# [run#0] [rewriting_time#06.sql] = 0
# [run#0] [rewriting_time#07.sql] = 0
# [run#0] [execution_time#01.sql] = 17
# [run#0] [unfolding_time#05.sql] = 0
# [run#0] [resultset_traversal_time#04.sql] = 0
# [run#0] [rewriting_time#11.sql] = 0
# [run#0] [unfolding_time#06.sql] = 0
# [run#0] [execution_time#09.sql] = 36
# [run#0] [rewriting_time#08.sql] = 0
# [run#0] [unfolding_time#11.sql] = 0
# [run#0] [resultset_traversal_time#03.sql] = 0
# [run#0] [rewriting_time#12.sql] = 0
# [run#0] [mix_time#0] = 404
# [run#3] [num_results#05.sql] = 929
# [run#3] [num_results#11.sql] = 12
# [run#3] [num_results#00.sql] = 67
# [run#3] [num_results#03.sql] = 52
# [run#3] [num_results#02.sql] = 1470
# [run#3] [num_results#07.sql] = 6
# [run#3] [num_results#09.sql] = 26
# [run#3] [num_results#12.sql] = 79
# [run#3] [num_results#01.sql] = 11
# [run#3] [num_results#06.sql] = 1
# [run#3] [num_results#04.sql] = 29
# [run#3] [num_results#08.sql] = 14
# [run#3] [num_results#10.sql] = 73
# [run#3] [mix_time#3] = 350
# [run#3] [rewriting_time#04.sql] = 0
# [run#3] [resultset_traversal_time#11.sql] = 0
# [run#3] [execution_time#07.sql] = 48
# [run#3] [unfolding_time#10.sql] = 0
# [run#3] [resultset_traversal_time#02.sql] = 0
# [run#3] [execution_time#08.sql] = 31
# [run#3] [unfolding_time#03.sql] = 0
# [run#3] [unfolding_time#12.sql] = 0
# [run#3] [rewriting_time#05.sql] = 0
# [run#3] [resultset_traversal_time#10.sql] = 0
# [run#3] [execution_time#06.sql] = 118
# [run#3] [unfolding_time#04.sql] = 0
# [run#3] [resultset_traversal_time#01.sql] = 0
# [run#3] [unfolding_time#00.sql] = 0
# [run#3] [resultset_traversal_time#05.sql] = 0
# [run#3] [rewriting_time#10.sql] = 0
# [run#3] [execution_time#05.sql] = 19
# [run#3] [resultset_traversal_time#00.sql] = 0
# [run#3] [unfolding_time#09.sql] = 0
# [run#3] [rewriting_time#02.sql] = 0
# [run#3] [resultset_traversal_time#06.sql] = 0
# [run#3] [unfolding_time#01.sql] = 0
# [run#3] [rewriting_time#03.sql] = 0
# [run#3] [execution_time#04.sql] = 22
# [run#3] [resultset_traversal_time#12.sql] = 0
# [run#3] [resultset_traversal_time#07.sql] = 0
# [run#3] [unfolding_time#02.sql] = 0
# [run#3] [unfolding_time#07.sql] = 0
# [run#3] [rewriting_time#09.sql] = 0
# [run#3] [execution_time#03.sql] = 17
# [run#3] [resultset_traversal_time#08.sql] = 0
# [run#3] [rewriting_time#00.sql] = 0
# [run#3] [execution_time#10.sql] = 26
# [run#3] [execution_time#12.sql] = 2
# [run#3] [resultset_traversal_time#09.sql] = 0
# [run#3] [unfolding_time#08.sql] = 0
# [run#3] [execution_time#02.sql] = 16
# [run#3] [rewriting_time#01.sql] = 0
# [run#3] [execution_time#11.sql] = 2
# [run#3] [execution_time#00.sql] = 1
# [run#3] [rewriting_time#06.sql] = 0
# [run#3] [rewriting_time#07.sql] = 0
# [run#3] [execution_time#01.sql] = 17
# [run#3] [unfolding_time#05.sql] = 0
# [run#3] [resultset_traversal_time#04.sql] = 0
# [run#3] [rewriting_time#11.sql] = 0
# [run#3] [unfolding_time#06.sql] = 0
# [run#3] [execution_time#09.sql] = 30
# [run#3] [rewriting_time#08.sql] = 0
# [run#3] [unfolding_time#11.sql] = 0
# [run#3] [resultset_traversal_time#03.sql] = 0
# [run#3] [rewriting_time#12.sql] = 0
# [run#2] [num_results#05.sql] = 871
# [run#2] [num_results#11.sql] = 12
# [run#2] [num_results#00.sql] = 54
# [run#2] [num_results#03.sql] = 21
# [run#2] [num_results#02.sql] = 1160
# [run#2] [num_results#07.sql] = 2
# [run#2] [num_results#09.sql] = 26
# [run#2] [num_results#12.sql] = 66
# [run#2] [num_results#01.sql] = 6
# [run#2] [num_results#06.sql] = 1
# [run#2] [num_results#04.sql] = 17
# [run#2] [num_results#08.sql] = 19
# [run#2] [num_results#10.sql] = 62
# [run#2] [rewriting_time#04.sql] = 0
# [run#2] [resultset_traversal_time#11.sql] = 0
# [run#2] [execution_time#07.sql] = 48
# [run#2] [unfolding_time#10.sql] = 0
# [run#2] [resultset_traversal_time#02.sql] = 0
# [run#2] [execution_time#08.sql] = 30
# [run#2] [unfolding_time#03.sql] = 0
# [run#2] [unfolding_time#12.sql] = 0
# [run#2] [rewriting_time#05.sql] = 0
# [run#2] [resultset_traversal_time#10.sql] = 0
# [run#2] [execution_time#06.sql] = 118
# [run#2] [unfolding_time#04.sql] = 0
# [run#2] [resultset_traversal_time#01.sql] = 0
# [run#2] [unfolding_time#00.sql] = 0
# [run#2] [resultset_traversal_time#05.sql] = 0
# [run#2] [rewriting_time#10.sql] = 0
# [run#2] [execution_time#05.sql] = 28
# [run#2] [resultset_traversal_time#00.sql] = 0
# [run#2] [unfolding_time#09.sql] = 0
# [run#2] [rewriting_time#02.sql] = 0
# [run#2] [resultset_traversal_time#06.sql] = 0
# [run#2] [unfolding_time#01.sql] = 0
# [run#2] [rewriting_time#03.sql] = 0
# [run#2] [execution_time#04.sql] = 22
# [run#2] [resultset_traversal_time#12.sql] = 0
# [run#2] [resultset_traversal_time#07.sql] = 0
# [run#2] [unfolding_time#02.sql] = 0
# [run#2] [unfolding_time#07.sql] = 0
# [run#2] [rewriting_time#09.sql] = 0
# [run#2] [execution_time#03.sql] = 16
# [run#2] [resultset_traversal_time#08.sql] = 0
# [run#2] [rewriting_time#00.sql] = 0
# [run#2] [execution_time#10.sql] = 25
# [run#2] [execution_time#12.sql] = 2
# [run#2] [resultset_traversal_time#09.sql] = 0
# [run#2] [unfolding_time#08.sql] = 0
# [run#2] [execution_time#02.sql] = 18
# [run#2] [rewriting_time#01.sql] = 0
# [run#2] [execution_time#11.sql] = 2
# [run#2] [execution_time#00.sql] = 1
# [run#2] [rewriting_time#06.sql] = 0
# [run#2] [rewriting_time#07.sql] = 0
# [run#2] [execution_time#01.sql] = 16
# [run#2] [unfolding_time#05.sql] = 0
# [run#2] [resultset_traversal_time#04.sql] = 0
# [run#2] [rewriting_time#11.sql] = 0
# [run#2] [unfolding_time#06.sql] = 0
# [run#2] [execution_time#09.sql] = 32
# [run#2] [rewriting_time#08.sql] = 0
# [run#2] [unfolding_time#11.sql] = 0
# [run#2] [resultset_traversal_time#03.sql] = 0
# [run#2] [rewriting_time#12.sql] = 0
# [run#2] [mix_time#2] = 358
# [run#9] [num_results#05.sql] = 331
# [run#9] [num_results#11.sql] = 12
# [run#9] [num_results#00.sql] = 145
# [run#9] [num_results#03.sql] = 12
# [run#9] [num_results#02.sql] = 3076
# [run#9] [num_results#07.sql] = 2
# [run#9] [num_results#09.sql] = 20
# [run#9] [num_results#12.sql] = 157
# [run#9] [num_results#01.sql] = 7
# [run#9] [num_results#06.sql] = 1
# [run#9] [num_results#04.sql] = 0
# [run#9] [num_results#08.sql] = 15
# [run#9] [num_results#10.sql] = 46
# [run#9] [rewriting_time#04.sql] = 0
# [run#9] [resultset_traversal_time#11.sql] = 0
# [run#9] [execution_time#07.sql] = 45
# [run#9] [mix_time#9] = 382
# [run#9] [unfolding_time#10.sql] = 0
# [run#9] [resultset_traversal_time#02.sql] = 0
# [run#9] [execution_time#08.sql] = 34
# [run#9] [unfolding_time#03.sql] = 0
# [run#9] [unfolding_time#12.sql] = 0
# [run#9] [rewriting_time#05.sql] = 0
# [run#9] [resultset_traversal_time#10.sql] = 0
# [run#9] [execution_time#06.sql] = 128
# [run#9] [unfolding_time#04.sql] = 0
# [run#9] [resultset_traversal_time#01.sql] = 0
# [run#9] [unfolding_time#00.sql] = 0
# [run#9] [resultset_traversal_time#05.sql] = 0
# [run#9] [rewriting_time#10.sql] = 0
# [run#9] [execution_time#05.sql] = 26
# [run#9] [resultset_traversal_time#00.sql] = 0
# [run#9] [unfolding_time#09.sql] = 0
# [run#9] [rewriting_time#02.sql] = 0
# [run#9] [resultset_traversal_time#06.sql] = 0
# [run#9] [unfolding_time#01.sql] = 0
# [run#9] [rewriting_time#03.sql] = 0
# [run#9] [execution_time#04.sql] = 22
# [run#9] [resultset_traversal_time#12.sql] = 0
# [run#9] [resultset_traversal_time#07.sql] = 0
# [run#9] [unfolding_time#02.sql] = 0
# [run#9] [unfolding_time#07.sql] = 0
# [run#9] [rewriting_time#09.sql] = 0
# [run#9] [execution_time#03.sql] = 16
# [run#9] [resultset_traversal_time#08.sql] = 0
# [run#9] [rewriting_time#00.sql] = 0
# [run#9] [execution_time#10.sql] = 25
# [run#9] [execution_time#12.sql] = 3
# [run#9] [resultset_traversal_time#09.sql] = 0
# [run#9] [unfolding_time#08.sql] = 0
# [run#9] [execution_time#02.sql] = 32
# [run#9] [rewriting_time#01.sql] = 0
# [run#9] [execution_time#11.sql] = 2
# [run#9] [execution_time#00.sql] = 2
# [run#9] [rewriting_time#06.sql] = 0
# [run#9] [rewriting_time#07.sql] = 0
# [run#9] [execution_time#01.sql] = 16
# [run#9] [unfolding_time#05.sql] = 0
# [run#9] [resultset_traversal_time#04.sql] = 0
# [run#9] [rewriting_time#11.sql] = 0
# [run#9] [unfolding_time#06.sql] = 0
# [run#9] [execution_time#09.sql] = 31
# [run#9] [rewriting_time#08.sql] = 0
# [run#9] [unfolding_time#11.sql] = 0
# [run#9] [resultset_traversal_time#03.sql] = 0
# [run#9] [rewriting_time#12.sql] = 0
# [run#8] [num_results#05.sql] = 530
# [run#8] [num_results#11.sql] = 12
# [run#8] [num_results#00.sql] = 132
# [run#8] [num_results#03.sql] = 48
# [run#8] [num_results#02.sql] = 2794
# [run#8] [num_results#07.sql] = 3
# [run#8] [num_results#09.sql] = 21
# [run#8] [num_results#12.sql] = 144
# [run#8] [num_results#01.sql] = 8
# [run#8] [num_results#06.sql] = 1
# [run#8] [num_results#04.sql] = 34
# [run#8] [num_results#08.sql] = 16
# [run#8] [num_results#10.sql] = 44
# [run#8] [rewriting_time#04.sql] = 0
# [run#8] [resultset_traversal_time#11.sql] = 0
# [run#8] [mix_time#8] = 393
# [run#8] [execution_time#07.sql] = 46
# [run#8] [unfolding_time#10.sql] = 0
# [run#8] [resultset_traversal_time#02.sql] = 0
# [run#8] [execution_time#08.sql] = 30
# [run#8] [unfolding_time#03.sql] = 0
# [run#8] [unfolding_time#12.sql] = 0
# [run#8] [rewriting_time#05.sql] = 0
# [run#8] [resultset_traversal_time#10.sql] = 0
# [run#8] [execution_time#06.sql] = 120
# [run#8] [unfolding_time#04.sql] = 0
# [run#8] [resultset_traversal_time#01.sql] = 0
# [run#8] [unfolding_time#00.sql] = 0
# [run#8] [resultset_traversal_time#05.sql] = 0
# [run#8] [rewriting_time#10.sql] = 0
# [run#8] [execution_time#05.sql] = 34
# [run#8] [resultset_traversal_time#00.sql] = 0
# [run#8] [unfolding_time#09.sql] = 0
# [run#8] [rewriting_time#02.sql] = 0
# [run#8] [resultset_traversal_time#06.sql] = 0
# [run#8] [unfolding_time#01.sql] = 0
# [run#8] [rewriting_time#03.sql] = 0
# [run#8] [execution_time#04.sql] = 25
# [run#8] [resultset_traversal_time#12.sql] = 0
# [run#8] [resultset_traversal_time#07.sql] = 0
# [run#8] [unfolding_time#02.sql] = 0
# [run#8] [unfolding_time#07.sql] = 0
# [run#8] [rewriting_time#09.sql] = 0
# [run#8] [execution_time#03.sql] = 21
# [run#8] [resultset_traversal_time#08.sql] = 0
# [run#8] [rewriting_time#00.sql] = 0
# [run#8] [execution_time#10.sql] = 24
# [run#8] [execution_time#12.sql] = 3
# [run#8] [resultset_traversal_time#09.sql] = 0
# [run#8] [unfolding_time#08.sql] = 0
# [run#8] [execution_time#02.sql] = 33
# [run#8] [rewriting_time#01.sql] = 0
# [run#8] [execution_time#11.sql] = 2
# [run#8] [execution_time#00.sql] = 1
# [run#8] [rewriting_time#06.sql] = 0
# [run#8] [rewriting_time#07.sql] = 0
# [run#8] [execution_time#01.sql] = 17
# [run#8] [unfolding_time#05.sql] = 0
# [run#8] [resultset_traversal_time#04.sql] = 0
# [run#8] [rewriting_time#11.sql] = 0
# [run#8] [unfolding_time#06.sql] = 0
# [run#8] [execution_time#09.sql] = 37
# [run#8] [rewriting_time#08.sql] = 0
# [run#8] [unfolding_time#11.sql] = 0
# [run#8] [resultset_traversal_time#03.sql] = 0
# [run#8] [rewriting_time#12.sql] = 0
